# %% [markdown]
# # Critical Thinking Rubric
# Weight of assessment in final grade: 20%
#
# Type of assessment: Individual
#
# Evaluator: Director CSBB

# %%
{
    "tags": [
        "remove-input"
    ]
}

from prettytable import PrettyTable

table = PrettyTable([" ","Learning Outcome","Criteria","Fail","Pass","Comments"])
table.add_row(["Collaborate","2.a. Collaborate effectively with other group members,\n other groups and the case owners / experts of the field. ", "The students' role(s) in the assigments (poster, proposal); The interaction with the supervisor and coach(es); The interaction with stakeholders"," "," "," "])
print(table)
# Out:
# +-------------+------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------+------+------+----------+
# |             |                      Learning Outcome                      |                                                                     Criteria                                                                     | Fail | Pass | Comments |
# +-------------+------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------+------+------+----------+
# ...

# %%
\begin{tabular}{c c c c c c }
& Learning Outcome & Criteria & Pass & Fail & Comments\\
\hline
Collaborate & Collaborate effectively with other group members, other groups and the case owners & The students roles in the assignments; The interaction with the supervisor and coaches & & & \\
\end{tabular}
# Out:
#   Cell In[8], line 1
#     \begin{tabular}{c c c c c c }
#      ^
# SyntaxError: unexpected character after line continuation character
